# %% [markdown]
# # हिंदी टेक्स्ट प्रोसेसिंग
# यह नोटबुक हिंदी शब्दों को समझने, टोकनाइज़ करने और गिनने के उदाहरण प्रस्तुत करती है।

# %% [markdown]
# ## 1. आवश्यक पुस्तकालय आयात करें
# Python फंक्शन और डेटा संरचनाएँ हिंदी पाठ को प्रोसेस करने में मदद करेंगी।

# %%
import re
from collections import Counter

print('लाइब्रेरी आयात हो गई।')

# %% [markdown]
# ## 2. हिंदी पाठ के उदाहरण परिभाषित करें
# यहां हम हिंदी वाक्य को Python स्ट्रिंग में स्टोर करेंगे।

# %%
hindi_text = 'कृष्ण की बनाई मूरत है, वह चाँद सी खूबसूरत है, जान निसार है उसमें, हां वह मेरी जरूरत है।'
extra_text = 'कृष्ण का तेज, प्रेम और भक्ति का स्वरूप है।'
print('हिंदी टेक्स्ट तैयार है।')

# %% [markdown]
# ## 3. हिंदी पाठ को सामान्य और टोकनाइज़ करें
# हम टेक्स्ट से विराम चिह्न हटाएंगे और शब्दों में विभाजित करेंगे।

# %%
def normalize_hindi(text):
    text = text.lower()
    text = re.sub(r'[\u0964\u0965.,!?;:\
